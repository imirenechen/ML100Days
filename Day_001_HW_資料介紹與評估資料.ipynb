# %% [markdown]
# ## 練習時間
# ### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# ### [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)
#
# ### [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, y_hat):
    """
    計算 MAE
    Args: y=實際值, y_hat=預測值
    Return: mae: MAE
    """
    mae = MAE = sum(abs(y-y_hat))/len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, y_hat):
    """
    計算 MSE
    Args: y=實際值, y_hat=預測值
    Return: mse: MSE
    """
    mse = MSE = sum((y-y_hat)**2)/len(y)
    return mse

# %%
w = 3
b = 0.5
# np.linspace(0, 100, 101)是指 0~100 劃分成 101 個刻度(含頭尾),也就是 0, 1, 2,...,100 這 101 個數
x_lin = np.linspace(0, 100, 101)
# np.random.randn() 就是隨機傳回標準常態分布的取樣值
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 加上預測的線性關係
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 231.188
# The Mean absolute error is 12.075

# %% [markdown]
# ### [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# [Competition: Student Performance prediction](https://www.kaggle.com/competitions/datasciencenigeria)
#
# 1. 你選的這組資料為何重要：<font color=#0000FF>預測學生的成績</font>
#
# 2. 資料從何而來(tips: 譬如提供者是誰、以什麼方式蒐集)：<font color=#0000FF>奈及利亞資料科學訓練營所提供的資料</font>
#
# 3. 蒐集而來的資料型態為何：<font color=#0000FF>結構化資料，包含學生與其父母的資訊和學生的學習資源</font>
#
# 4. 這組資料想解決的問題如何評估：<font color=#0000FF>使用Linear Regression預測，評估方法為MAE、MSE、RMSE</font>
#
# ### [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何(tips：如何定義 「提升業績 & 你的假設」)
# <font color=#0000FF>假設：如何降低空車的時間</font>
#
# 2. 資料從何而來(tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# <font color=#0000FF>哪些時段、在哪裡會有較多的客源
# (1) APP註冊用戶資料：客戶啟程與結束地點、客戶交通時段等
# (2) 政府開放資料集：各商圈人流熱點資訊、交通離尖峰時段等</font>
#
# 3. 蒐集而來的資料型態為何
# <font color=#0000FF>結構化資料</font>
#
# 4. 你要回答的問題，其如何評估(tips：你的假設如何驗證)
# <font color=#0000FF>預測地區與時段區間，應可使用分類模型預測，可用Accuracy評估</font>
