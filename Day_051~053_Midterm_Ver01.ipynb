# %% [markdown]
# # ML100Marathon Midterm
# - [Enron Fraud Dataset 安隆公司詐欺案資料集](https://www.kaggle.com/competitions/2021-ml100marathon-midterm)

# %% [markdown]
# ## Step1 定義問題
# - 這個問題是如何產生的？安隆公司曾是間能源公司，卻於2002年宣告破產，揭露其財報造假的醜聞，而本次的問題在於找出可疑的詐欺犯
# - 它提供了哪些資訊、資料與變數？薪水、獎金、長期獎勵、延期收入/付款、貨代墊款、董事費、股票價值等等
# - 這個問題的預期產出是什麼？找出可疑的詐欺犯罪者(Person of Interest,POI)
# - 會對這個問題可以產生什麼結果？同上
#
# ### 選擇什麼方法？
# 1. 該問題是監督還是非監督學習？監督式學習
# 2. 該問題的結果是分類還是回歸？分類
#
# ## Step2 區分與整理 Train／Test 資料集

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# 讀取資料
df_train = pd.read_csv("train_data.csv")
df_test = pd.read_csv("test_features.csv")
df_train.head()
# Out:
#                    name      bonus  deferral_payments  deferred_income  \
# 0        RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1    SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2            SHELBY REX   200000.0                NaN          -4167.0
# 3      KOPPER MICHAEL J   800000.0                NaN              NaN
# 4  CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
#
#    director_fees                 email_address  exercised_stock_options  \
# 0            NaN            ken.rice@enron.com               19794175.0
# 1            NaN       jeff.skilling@enron.com               19250000.0
# 2            NaN          rex.shelby@enron.com                1624396.0
# 3            NaN      michael.kopper@enron.com                      NaN
# 4            NaN  christopher.calger@enron.com                      NaN
#
#    expenses  from_messages  from_poi_to_this_person  ...  long_term_incentive  \
# ...

# %% [markdown]
# ## Step3 進行探索式資料分析(EDA)
# EDA (Exploratory Data Analysis)
# 1. 確認資料狀況
# 2. 樞紐分析與視覺化
#
# ### A. 確認資料狀況
# 1. 檢視欄位的種類
# 2. 檢視資料的型態：名目/類別屬性、次序/順序屬性、等距/區間屬性、比率/比例屬性
# 3. 檢視錯誤與分布

# %%
# 合併訓練與測試資料集
# test data和train data欄位差異:沒有poi欄位
train_Y = df_train["poi"]
df_train = df_train.drop(["poi"], axis=1)
df = pd.concat([df_train,df_test], ignore_index=True)
print(df.shape)
df.head()
# Out:
# (146, 21)
#                    name      bonus  deferral_payments  deferred_income  \
# 0        RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1    SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2            SHELBY REX   200000.0                NaN          -4167.0
# 3      KOPPER MICHAEL J   800000.0                NaN              NaN
# 4  CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
#
#    director_fees                 email_address  exercised_stock_options  \
# 0            NaN            ken.rice@enron.com               19794175.0
# 1            NaN       jeff.skilling@enron.com               19250000.0
# 2            NaN          rex.shelby@enron.com                1624396.0
# 3            NaN      michael.kopper@enron.com                      NaN
# 4            NaN  christopher.calger@enron.com                      NaN
#
#    expenses  from_messages  from_poi_to_this_person  ...  loan_advances  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   name                       146 non-null    object
#  1   bonus                      82 non-null     float64
#  2   deferral_payments          39 non-null     float64
#  3   deferred_income            49 non-null     float64
#  4   director_fees              17 non-null     float64
#  5   email_address              111 non-null    object
#  6   exercised_stock_options    102 non-null    float64
#  7   expenses                   95 non-null     float64
#  8   from_messages              86 non-null     float64
#  9   from_poi_to_this_person    86 non-null     float64
#  10  from_this_person_to_poi    86 non-null     float64
#  11  loan_advances              4 non-null      float64
#  12  long_term_incentive        66 non-null     float64
# ...

# %%
# 檢查缺失值
def na_check(df_data):
    data_na = (df_data.isnull().sum() / len(df_data)) * 100
    data_na = data_na.drop(data_na[data_na == 0].index).sort_values(ascending=False)
    missing_data = pd.DataFrame({"Missing Ratio" : data_na})
    display(missing_data)
na_check(df)
# Out:
#                            Missing Ratio
# loan_advances                  97.260274
# director_fees                  88.356164
# restricted_stock_deferred      87.671233
# deferral_payments              73.287671
# deferred_income                66.438356
# long_term_incentive            54.794521
# bonus                          43.835616
# from_messages                  41.095890
# from_poi_to_this_person        41.095890
# from_this_person_to_poi        41.095890
# shared_receipt_with_poi        41.095890
# to_messages                    41.095890
# other                          36.301370
# expenses                       34.931507
# salary                         34.931507
# exercised_stock_options        30.136986
# restricted_stock               24.657534
# email_address                  23.972603
# total_payments                 14.383562
# total_stock_value              13.698630

# %% [markdown]
# ### 資料狀況筆記
# - 除了```name```欄位外, 其餘所有欄位都有缺失值
# - 缺失值太多的欄位, 如: ```loan_advances```, ```director_fees```, ```restricted_stock_deferred```, 可考慮移除
#
# ### B. 樞紐分析與視覺化
# 1. 檢視資料的分布
# 2. 樞紐分析與圖例

# %%
# email相關特徵: 除了email_address,其餘為次數(以下五個欄位)
email_features=["from_messages","from_poi_to_this_person","from_this_person_to_poi","shared_receipt_with_poi","to_messages"]
df[email_features].head()
# Out:
#    from_messages  from_poi_to_this_person  from_this_person_to_poi  \
# 0           18.0                     42.0                      4.0
# 1          108.0                     88.0                     30.0
# 2           39.0                     13.0                     14.0
# 3            NaN                      NaN                      NaN
# 4          144.0                    199.0                     25.0
#
#    shared_receipt_with_poi  to_messages
# 0                    864.0        905.0
# 1                   2042.0       3627.0
# 2                     91.0        225.0
# 3                      NaN          NaN
# 4                   2188.0       2598.0

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(18,9))
for i in range(len(email_features)):
    plt.subplot(2,3,i+1)
    plt.hist(df[email_features[i]],color=sns.color_palette()[0])
    plt.title(str(email_features[i]))
plt.show()

# %%
# Stock value相關特徵
stock_features=["exercised_stock_options","restricted_stock","restricted_stock_deferred","total_stock_value"]
df[stock_features].head()
# Out:
#    exercised_stock_options  restricted_stock  restricted_stock_deferred  \
# 0               19794175.0         2748364.0                        NaN
# 1               19250000.0         6843672.0                        NaN
# 2                1624396.0          869220.0                        NaN
# 3                      NaN          985032.0                        NaN
# 4                      NaN          126027.0                        NaN
#
#    total_stock_value
# 0         22542539.0
# 1         26093672.0
# 2          2493616.0
# 3           985032.0
# 4           126027.0

# %%
plt.figure(figsize=(18,9))
for i in range(len(stock_features)):
    plt.subplot(2,3,i+1)
    plt.hist(df[stock_features[i]],color=sns.color_palette()[1])
    plt.title(str(stock_features[i]))
plt.show()

# %%
# Payments相關特徵
payment_features=["bonus","deferral_payments","deferred_income","director_fees","expenses",
                 "loan_advances","long_term_incentive","other","salary","total_payments"]
df[payment_features].head()
# Out:
#        bonus  deferral_payments  deferred_income  director_fees  expenses  \
# 0  1750000.0                NaN       -3504386.0            NaN   46950.0
# 1  5600000.0                NaN              NaN            NaN   29336.0
# 2   200000.0                NaN          -4167.0            NaN   22884.0
# 3   800000.0                NaN              NaN            NaN  118134.0
# 4  1250000.0                NaN        -262500.0            NaN   35818.0
#
#    loan_advances  long_term_incentive      other     salary  total_payments
# 0            NaN            1617011.0   174839.0   420636.0        505050.0
# 1            NaN            1920000.0    22122.0  1111258.0       8682716.0
# 2            NaN                  NaN  1573324.0   211844.0       2003885.0
# 3            NaN             602671.0   907502.0   224305.0       2652612.0
# 4            NaN             375304.0      486.0   240189.0       1639297.0

# %%
plt.figure(figsize=(18,18))
for i in range(len(payment_features)):
    plt.subplot(4,3,i+1)
    plt.hist(df[payment_features[i]],color=sns.color_palette()[2])
    plt.title(str(payment_features[i]))
plt.show()

# %% [markdown]
# ### EDA筆記
# - 從柱狀圖來看, 特徵值都呈偏邊分布, 可以進行"去除偏態"處理

# %% [markdown]
# ## Step4 清理資料
#
# ### A. 檢查資料與確認缺失值
# 1. 是否有遺漏值/缺失值 (Missing value):
#    <font color=#0000FF>除了```name```欄位外, 其餘所有欄位都有缺失值
# 缺失值太多的欄位, 如: ```loan_advances```, ```director_fees```, ```restricted_stock_deferred```, 可考慮移除</font>
# 2. 是否有極值或異常值 (Outlier)
#    <font color=#0000FF>從柱狀圖來看, 特徵值都呈偏邊分布, 可以進行"去除偏態"處理 (因資料較少,為避免移除不該移除的資料的做法)</font>
# 3. 資料分布是否符合常態 (Normal Distribution): <font color=#0000FF>同上</font>
# 4. 資料是否需要清洗 (Clean Data)
#    <font color=#0000FF>```name```是否可取出最後的代碼後做one-hot encoding</font>
#
# ### B. 進行資料加工
# <font color=#0000FF>待辦清單</font>
# 1. DataFrame.copy() 先複製出一份新的資料
# 2. 移除缺失值太多的欄位```loan_advances```, ```director_fees```, ```restricted_stock_deferred```和```name```, ```email_address```
# 3. 剩餘缺失值欄位: 以```fillna(0)```填補後, 使用log去偏態
# 4. 完成後, 確認缺失值與目前的資料表內容

# %%
# 1. DataFrame.copy() 先複製出一份新的資料
df_work = df.copy()

# 2. 移除缺失值太多的欄位loan_advances, director_fees, restricted_stock_deferred和name, email_address
df_work = df_work.drop(["loan_advances", "director_fees", "restricted_stock_deferred", "name", "email_address"], axis=1)

# 3. 剩餘缺失值欄位: 以fillna(0)填補後, 使用log去偏態
df_work = df_work.fillna(0)
for i in list(df_work.columns):
    df_work[i] = df_work[i].map(lambda i: np.log(i) if i > 0 else 0)
    
# 4. 完成後, 確認缺失值與目前的資料表內容
na_check(df_work)
print(df_work.shape)
df_work.head()
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []
# (146, 16)
#        bonus  deferral_payments  deferred_income  exercised_stock_options  \
# 0  14.375126                0.0                0                16.800898
# 1  15.538277                0.0                0                16.773022
# 2  12.206073                0.0                0                14.300647
# 3  13.592367                0.0                0                 0.000000
# 4  14.038654                0.0                0                 0.000000
#
#     expenses  from_messages  from_poi_to_this_person  from_this_person_to_poi  \
# 0  10.756838       2.890372                 3.737670                 1.386294
# 1  10.286571       4.682131                 4.477337                 3.401197
# 2  10.038193       3.663562                 2.564949                 2.639057
# 3  11.679575       0.000000                 0.000000                 0.000000
# ...

# %%
df_work.describe()
# Out:
#             bonus  deferral_payments  deferred_income  \
# count  146.000000         146.000000            146.0
# mean     7.648412           3.308119              0.0
# std      6.825947           5.672038              0.0
# min      0.000000           0.000000              0.0
# 25%      0.000000           0.000000              0.0
# 50%     12.611538           0.000000              0.0
# 75%     13.592367           9.172510              0.0
# max     18.393758          17.283849              0.0
#
#        exercised_stock_options    expenses  from_messages  \
# count               146.000000  146.000000     146.000000
# mean                  9.729574    6.789089       2.581567
# std                   6.565177    5.121819       2.556808
# min                   0.000000    0.000000       0.000000
# 25%                   0.000000    0.000000       0.000000
# 50%                  13.318412    9.910311       2.802901
# 75%                  14.354348   10.891905       3.936388
# ...

# %% [markdown]
# ## Step5 模型建置與預測
#
# ### A. 特徵預處理 (Preprocessing)
# 使用```最大最小化```平衡特徵(已經有使用log去偏態還需使用? 對非樹狀模型才有影響)

# %%
from sklearn.preprocessing import MinMaxScaler
df_work = MinMaxScaler().fit_transform(df_work)

# %% [markdown]
# ### B. 準備訓練／測試集 (Train / Test Split)

# %%
# 將df_work , 重新切成 train_X, test_X
train_num = train_Y.shape[0]
train_X = df_work[:train_num]
test_X = df_work[train_num:]

# 區分訓練集與測試集
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, test_size=0.3, random_state=10)

# %% [markdown]
# ### C. 訓練與評估模型 (Model Training)
# 使用default參數、設定random_state=10做預測
# 1. Logistic Regression
# 2. Decision Tree
# 3. Random Forest
# 4. Gradient Boosting

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score

# %% [markdown]
# ### Logistic Regression

# %%
# 使用default參數預測
lr = LogisticRegression(random_state=10)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print("Logistic Regression Accuracy: %.3f" % accuracy_score(y_test, y_pred))
# Out:
# Logistic Regression Accuracy: 0.882

# %% [markdown]
# ### Decision Tree

# %%
# 使用default參數預測
dt = DecisionTreeClassifier(random_state=10)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
print("Decision Tree Accuracy: %.3f" % accuracy_score(y_test, y_pred))
# Out:
# Decision Tree Accuracy: 0.912

# %%
# 調整參數
max_depths = list(range(1,21))
min_samples_splits = list(range(1,21))
min_samples_leaves = list(range(1,21))
param_grid = {"max_depth":max_depths,"min_samples_split":min_samples_splits, "min_samples_leaf":min_samples_leaves}

RSCV = RandomizedSearchCV(dt, param_grid, scoring="accuracy", random_state=10, n_jobs=-1, verbose=1)
search_result = RSCV.fit(X_train, y_train)
print("Best Accuracy: %.3f using %s" % (search_result.best_score_, search_result.best_params_))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Accuracy: 0.912 using {'min_samples_split': 10, 'min_samples_leaf': 5, 'max_depth': 4}

# %%
dt_bestparam = RSCV.best_estimator_
dt_bestparam.fit(X_train, y_train)
y_pred = dt_bestparam.predict(X_test)
print("Decision Tree Accuracy: %.3f" % accuracy_score(y_test, y_pred))
# Out:
# Decision Tree Accuracy: 0.912

# %% [markdown]
# ### Random Forest

# %%
# 使用default參數預測
rf = RandomForestClassifier(random_state=10)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("Random Forest Accuracy: %.3f" % accuracy_score(y_test, y_pred))
# Out:
# Random Forest Accuracy: 0.882

# %%
# 調整參數
n_estimators = list(range(5,105,5))
max_depths = list(range(1,21))
min_samples_splits = list(range(1,21))
min_samples_leaves = list(range(1,21))
param_grid = {"n_estimators":n_estimators,"max_depth":max_depths,
              "min_samples_split":min_samples_splits,"min_samples_leaf":min_samples_leaves}

RSCV = RandomizedSearchCV(rf, param_grid, scoring="accuracy", random_state=10, n_jobs=-1, verbose=1)
search_result = RSCV.fit(X_train, y_train)
print("Best Accuracy: %.3f using %s" % (search_result.best_score_, search_result.best_params_))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Accuracy: 0.912 using {'n_estimators': 10, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_depth': 3}

# %%
rf_bestparam = RSCV.best_estimator_
rf_bestparam.fit(X_train, y_train)
y_pred = rf_bestparam.predict(X_test)
print("Random Forest Accuracy: %.3f" % accuracy_score(y_test, y_pred))
# Out:
# Random Forest Accuracy: 0.853

# %% [markdown]
# ### Gradient Boosting Machine

# %%
# 使用default參數預測
gb = GradientBoostingClassifier(random_state=10)
gb.fit(X_train, y_train)
y_pred = gb.predict(X_test)
print("Gradient Boosting Accuracy: %.3f" % accuracy_score(y_test, y_pred))
# Out:
# Gradient Boosting Accuracy: 0.853

# %%
# 調整參數
n_estimators = list(range(5,105,5))
max_depths = list(range(1,21))
min_samples_splits = list(range(1,21))
min_samples_leaves = list(range(1,21))
param_grid = {"n_estimators":n_estimators,"max_depth":max_depths,
              "min_samples_split":min_samples_splits,"min_samples_leaf":min_samples_leaves}

RSCV = RandomizedSearchCV(gb, param_grid, scoring="accuracy", random_state=10, n_jobs=-1, verbose=1)
search_result = RSCV.fit(X_train, y_train)
print("Best Accuracy: %.3f using %s" % (search_result.best_score_, search_result.best_params_))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Accuracy: 0.899 using {'n_estimators': 65, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_depth': 2}

# %%
gb_bestparam = RSCV.best_estimator_
gb_bestparam.fit(X_train, y_train)
y_pred = gb_bestparam.predict(X_test)
print("Random Forest Accuracy: %.3f" % accuracy_score(y_test, y_pred))
# Out:
# Random Forest Accuracy: 0.882

# %% [markdown]
# ### 模型評估筆記
# - 使用```RandomizedSearchCV```找出的最佳參數通常可以提高模型的準確率(但不一定, 如上述Random Forest結果, 但也有可能是因為參數選擇不佳)
# - 初步使用四種模型Decision Tree(Default)的結果就很不錯
# - 使用```Decision Tree(Default)```和```Blending```結果先測試一版

# %%
dt.fit(train_X, train_Y)
dt_pred = dt.predict_proba(test_X)[:,1]
sub = pd.DataFrame({"name": df_test["name"], "poi": dt_pred})
sub.to_csv("poi_dt.csv", index=False)

# %%
rf.fit(train_X, train_Y)
rf_pred = rf.predict_proba(test_X)[:,1]
gb.fit(train_X, train_Y)
gb_pred = gb.predict_proba(test_X)[:,1]
blending_pred = dt_pred*0.4 + rf_pred*0.4 + gb_pred*0.2
sub = pd.DataFrame({"name": df_test["name"], "poi": blending_pred})
sub.to_csv("poi_blending.csv", index=False)

# %% [markdown]
# ![image.png](attachment:image.png)
